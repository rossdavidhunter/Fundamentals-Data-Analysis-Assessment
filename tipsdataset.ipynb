# %% [markdown]
# # Fundamentals of Data Analysis Assignment
#
# This jupyter notebook is to complete assisgnment on well -know tips dataset using seaborn python package and jupyter lab notebook.
#
# Data visulaization is very important in data analysis as it helps identify relationships between the variables. For this assisgment we will use the seaborn package and tips dataset. Seaborn is a data visualization libary that creates nice visualtions in the form of plots. To aide this visualization we will also use matplotlib, numpy and pandas packages.
#
# From diagram below Exploratory Data Analysis (EDA) is an approach in analyzing data sets to summarize main charateristics using various visual methods as seen below. Its primary use is to tell us what data means beyond formal modelling or testing tasks. Some of the example techniques used are as follows and will be used in this assignment along with others to provide descriptive statistics:
#
# 1. Histograms
# 2. Scatter Plots
# 3. Box Plots
# 4. Violin Plots
# 5. Pair Plots

# %% [markdown]
# ![](EDA.PNG)

# %%
# Importing of packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# use of magic function to help ensure plots show correctly

# %matplotlib inline

# %% [markdown]
# # 1. Loading of Dataset from Seaborn

# %%
# This will load in tips dataset from seaborn package

tips = sns.load_dataset("tips")

# %% [markdown]
# # 2. Quick look at what is contained in dataset

# %%
# Use of head and tail function will show data at start and end of dataset to give you a feel of what is contained in dataset.

tips.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
tips.tail(20)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# ...

# %% [markdown]
# # 3. Breakdown of Count, Mean, Std Dev etc

# %%
# Use of head and tail function will show data at start and end of dataset to give you a feel of what is contained in dataset.

tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # 4. Shape of dataset

# %%
# This will return info on number of rows and columns.

tips.shape
# Out:
# (244, 7)

# %% [markdown]
# # 5. Relationship between total bill and tip

# %%
# use of replot function to show data of total bill vs tips

sns.relplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
# use of jointplot function which displays both points and histograms

sns.jointplot(x = "total_bill", y = "tip", data = tips, color="purple")
plt.show()

# %%
# use of replot function again but with use of 'kind' that displays data as a line

sns.relplot(x="total_bill", y="tip", kind="line", data=tips)
plt.show()

# %% [markdown]
# What we can see from first 2 plots above is that the relationship between total bill and tip is showing a strong concentration that when the bill is between 10 and 20, tips between 2 and 4 are given.
#
# The 3rd plot we can see that distribution is too random for tips with respect to total_bill. We can can conclude that the tip is not dependent on the value of total_bill.

# %% [markdown]
# # 6. Histogram
#
# Use of histogram plot shows the tips given are concentrated around 2-4 values. Changing of bin values will change the way the data is spread out as seen below.

# %%
# use of distplot function with option of kernel desity estimate plot

sns.distplot(tips['tip'], kde=False, bins=10)
plt.show()
sns.distplot(tips['tip'], kde=True, bins=20)
plt.show()

# %% [markdown]
# # 7. Scatterplot
#
# Use of scatterplot is useful when you want to understand relationship between 2 varaiables. As seen below there is a high concentration of total bill between 10 and 30 for Thurs, Sat and Sun. Friday shows a low concentration around 10-20 mark.

# %%
# use of catplot function to show plot of total bill vs day of week

sns.catplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
# use of catplot with jitter function that controls magnitude of jitter

sns.catplot(x="day", y="total_bill", jitter=False, data=tips)
plt.show()

# %% [markdown]
# # 8. Boxplot
#
# A Box Plot is a visual representation of five point summary statistics of a given data set. A five number summary includes:
# ![](BP.PNG)
# 1. Minimum
# 2. First Quartile
# 3. Median (Second Quartile)
# 4. Third Quartile
# 5. Maximum
#
# You can add in hue to split boxplot for example smokers and non smokers. From below you can see the highest bills are concentrated around smokers.

# %%
# use of catplot function with kind set to 'box' to get boxplot

sns.catplot(x="day", y="total_bill", kind="box", data=tips)
plt.show()

# %%
# use of boxplot function with additional data of hue set to smoker

sns.boxplot(x = "day", y = "total_bill", data=tips, hue = "smoker")
plt.show()

# %% [markdown]
# # 9. Violin Plots
#
# These are similar to boxplots. See image below for comparison.
#
# ![](Image.PNG)

# %%
# use of catplot function with kind set to 'violin' to get  violin plot

sns.catplot(x="day", y="total_bill", hue="sex",kind="violin", data=tips)
plt.show()

# %% [markdown]
# # 10. Point Plots
#
# A point represents an estimate of central tendancy for a numeric variable. They show only mean values and error rates surrounding those mean values. They are useful in finding change in variable.
# Below you can see that the total bill rises from Thursday to Sunday for males while it decreases from Thursday to Friday, rises on Sat and remains flat across Sunday for females.

# %%
# use of catplot function with kind set to 'point' to get point plot

sns.catplot(x="day", y="total_bill", hue="sex", kind="point", data=tips)
plt.show()

# %% [markdown]
# # 11. Pairplot
#
# The diagonal part shows the distplot or histogram with kernel density estimation. The upper and lower part of the Pairplot shows the scatterplot. The “hue” colours the plot using categorical columns.
# hue = “sex” — It will color the plot gender wise.
# palette = “Set1” is a type of color combination used to color the plot

# %%
# use of pairplot function

sns.pairplot(tips, hue = "sex", palette="Set1")
plt.show()

# %% [markdown]
# # 12. JointPlots
#
# A jointplot takes two variables and as seen below creates a histogram and scatterplot. The second plot is a contour plot and a Kerner Density Estimate (KDE) plot.

# %%
# use of jointplot function

sns.jointplot(x = "total_bill", y = "tip", data = tips, color="purple")
plt.show()

# %%
# use of jointplot set with kde

sns.jointplot(x = tips["total_bill"], y = tips["tip"],kind = "kde", 
color="purple")
plt.show()

# %% [markdown]
# # 13. Barplots
#
# Barplots are meant for plotting categorical columns vs numerical columns. It creates bar in visualisation.

# %%
# Use of barplot function

sns.barplot(x ="sex" , y ="total_bill" , data=tips)
plt.show()

# %%
sns.barplot(x = "smoker", y = "total_bill", data =tips)
plt.show()

# %%
sns.barplot(x = "day", y = "total_bill", data =tips)
plt.show()

# %% [markdown]
# # 14. LM Plots
#
# sns.lmplot is a plot that fits the regression line to the dataset showing as scatterplots. It follows the ordinary least square method and the line represents the best fit line.
# This shows the linear regression fit of total_bill variable for the different days as shown in the plot legend. This is obtained using hue = “day” in sns.lmplot.

# %%
# use of lmplot function

sns.lmplot(x = "total_bill", y = "tip", data = tips, hue="day")
plt.show()

# %%
# use of lmplot for total bill and tip

sns.set_style('darkgrid') 
sns.lmplot(x ='total_bill', y ='tip', data = tips)
plt.show()

# %% [markdown]
# # 15. References

# %% [markdown]
# 1. https://seaborn.pydata.org/tutorial/color_palettes.html
# 2. https://amitkushwaha.co.in/data-visualization-part-1.html
# 3. https://towardsdatascience.com/analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e
# 4. https://medium.com/@mukul.mschauhan/data-visualisation-using-seaborn-464b7c0e5122
# 5. https://en.wikipedia.org/wiki/Exploratory_data_analysis
# 6. http://www.jeannjorog.e.com/significance-of-exploratory-data-anaysis/
# 7. https://seaborn.pydata.org/tutorial.html
# 8. https://seaborn.pydata.org/examples/index.html
